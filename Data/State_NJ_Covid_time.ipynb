# %%
import pandas as pd
import numpy as np
import requests
import time

# %%
d_state_covid = pd.read_csv("NJ state time series.csv" )
d_state_covid.head()
# Out:
#          date country state           county   fips  lat  long  \
# 0  2020-01-22      US    NJ  Atlantic County  34001  NaN   NaN
# 1  2020-01-23      US    NJ  Atlantic County  34001  NaN   NaN
# 2  2020-01-24      US    NJ  Atlantic County  34001  NaN   NaN
# 3  2020-01-25      US    NJ  Atlantic County  34001  NaN   NaN
# 4  2020-01-26      US    NJ  Atlantic County  34001  NaN   NaN
#
#                       locationId  actuals.cases  actuals.deaths  ...  \
# 0  iso1:us#iso2:us-nj#fips:34001            NaN             NaN  ...
# 1  iso1:us#iso2:us-nj#fips:34001            NaN             NaN  ...
# 2  iso1:us#iso2:us-nj#fips:34001            NaN             NaN  ...
# 3  iso1:us#iso2:us-nj#fips:34001            NaN             NaN  ...
# 4  iso1:us#iso2:us-nj#fips:34001            NaN             NaN  ...
#
#    metrics.infectionRate  metrics.infectionRateCI90  metrics.icuHeadroomRatio  \
# 0                    NaN                        NaN                       NaN
# ...
