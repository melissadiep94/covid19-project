# %%
import requests
import json
import pandas as pd

# %%
pop = "https://api.census.gov/data/2019/pep/charagegroups?get=NAME,POP&for=county:*&in=state:34&key=52e4b71218eb4d492e49c7dcde830174d23a8db9"

# %%
response = requests.get(pop)
print(response.url)
# Out:
# https://api.census.gov/data/2019/pep/charagegroups?get=NAME,POP&for=county:*&in=state:34&key=52e4b71218eb4d492e49c7dcde830174d23a8db9

# %%
print(json.dumps(pop_data, indent=4, sort_keys=True))
# Out:
# [
#     [
#         "NAME",
#         "POP",
#         "state",
#         "county"
#     ],
#     [
#         "Monmouth County, New Jersey",
#         "618795",
#         "34",
#         "025"
#     ],
#     [
#         "Mercer County, New Jersey",
#         "367430",
#         "34",
#         "021"
#     ],
#     [
#         "Sussex County, New Jersey",
#         "140488",
#         "34",
#         "037"
#     ],
#     [
#         "Cumberland County, New Jersey",
#         "149527",
#         "34",
#         "011"
#     ],
#     [
#         "Somerset County, New Jersey",
#         "328934",
#         "34",
#         "035"
#     ],
#     [
#         "Essex County, New Jersey",
#         "798975",
#         "34",
#         "013"
#     ],
#     [
#         "Ocean County, New Jersey",
#         "607186",
#         "34",
#         "029"
#     ],
#     [
#         "Atlantic County, New Jersey",
#         "263670",
#         "34",
#         "001"
#     ],
#     [
#         "Gloucester County, New Jersey",
#         "291636",
#         "34",
#         "015"
#     ],
#     [
#         "Salem County, New Jersey",
#         "62385",
#         "34",
#         "033"
#     ],
#     [
#         "Passaic County, New Jersey",
#         "501826",
#         "34",
#         "031"
#     ],
#     [
#         "Cape May County, New Jersey",
#         "92039",
#         "34",
#         "009"
#     ],
#     [
#         "Camden County, New Jersey",
#         "506471",
#         "34",
#         "007"
#     ],
#     [
#         "Bergen County, New Jersey",
#         "932202",
#         "34",
#         "003"
#     ],
#     [
#         "Union County, New Jersey",
#         "556341",
#         "34",
#         "039"
#     ],
#     [
#         "Warren County, New Jersey",
#         "105267",
#         "34",
#         "041"
#     ],
#     [
#         "Hudson County, New Jersey",
#         "672391",
#         "34",
#         "017"
#     ],
#     [
#         "Hunterdon County, New Jersey",
#         "124371",
#         "34",
#         "019"
#     ],
#     [
#         "Burlington County, New Jersey",
#         "445349",
#         "34",
#         "005"
#     ],
#     [
#         "Morris County, New Jersey",
#         "491845",
#         "34",
#         "027"
#     ],
#     [
#         "Middlesex County, New Jersey",
#         "825062",
#         "34",
#         "023"
#     ]
# ]

# %%
pop_data = response.json()
pop_df = pd.DataFrame((pop_data), columns=("County","Population","State_Num","County_Num"))
pop_df = pop_df.drop(0).reset_index(drop=True)
pop_df["County"] = pop_df["County"].str.split(',',expand=True)
pop_df["County_Num"] = pop_df["State_Num"] + pop_df["County_Num"]
pop_df
# Out:
#                County Population State_Num County_Num
# 0     Monmouth County     618795        34      34025
# 1       Mercer County     367430        34      34021
# 2       Sussex County     140488        34      34037
# 3   Cumberland County     149527        34      34011
# 4     Somerset County     328934        34      34035
# 5        Essex County     798975        34      34013
# 6        Ocean County     607186        34      34029
# 7     Atlantic County     263670        34      34001
# 8   Gloucester County     291636        34      34015
# 9        Salem County      62385        34      34033
# 10     Passaic County     501826        34      34031
# 11    Cape May County      92039        34      34009
# 12      Camden County     506471        34      34007
# 13      Bergen County     932202        34      34003
# 14       Union County     556341        34      34039
# 15      Warren County     105267        34      34041
# 16      Hudson County     672391        34      34017
# 17   Hunterdon County     124371        34      34019
# 18  Burlington County     445349        34      34005
# 19      Morris County     491845        34      34027
# 20   Middlesex County     825062        34      34023
