# %%
# Dependencies
import requests
import json
import pandas as pd
import numpy as np

# %%
#API from CDC; shows # of NJ cases by county for June 2021

url = "https://data.cdc.gov/resource/n8mc-b4w4.json?res_state=NJ&case_month=2021-06&$limit=20000"

#how to filter for NJ first, date, and then 20000 cases?

# %%
response = requests.get(url)
print(response.url)
# Out:
# https://data.cdc.gov/resource/n8mc-b4w4.json?res_state=NJ&case_month=2021-06&$limit=20000

# %%
data = response.json()
# Use json.dumps to print the json
#print(json.dumps(data, indent=4, sort_keys=True))

#print data frame

df = pd.DataFrame(data)
df
# Out:
#      case_month res_state state_fips_code  res_county county_fips_code  \
# 0       2021-06        NJ              34  CUMBERLAND            34011
# 1       2021-06        NJ              34  CUMBERLAND            34011
# 2       2021-06        NJ              34  CUMBERLAND            34011
# 3       2021-06        NJ              34  CUMBERLAND            34011
# 4       2021-06        NJ              34  CUMBERLAND            34011
# ...         ...       ...             ...         ...              ...
# 5499    2021-06        NJ              34          NA               NA
# 5500    2021-06        NJ              34          NA               NA
# 5501    2021-06        NJ              34          NA               NA
# 5502    2021-06        NJ              34          NA               NA
# 5503    2021-06        NJ              34          NA               NA
#
#            age_group     sex race ethnicity case_onset_interval  process  \
# ...

# %%
#Total # of cases

num_cases = df["res_state"].count()

df_total_cases = pd.DataFrame({"Total # of NJ cases in June 2021":[num_cases]})
df_total_cases
# Out:
#    Total # of NJ cases in June 2021
# 0                              5504

# %%
#Group by county
#county = df.groupby(['res_state','res_county']).count()

#county = df.groupby(['res_state','res_county']).size()

num_cases_county = df['res_county'].value_counts()

num_cases_county_percentage = (num_cases_county/ num_cases  ) * 100


county_df = pd.DataFrame({"Total # of Cases by NJ County in June 2021": num_cases_county, "Percentage": num_cases_county_percentage })
county_df_descending = county_df.sort_values('Total # of Cases by NJ County in June 2021',ascending=False)
county_df_descending.round()
# Out:
#             Total # of Cases by NJ County in June 2021  Percentage
# MONMOUTH                                           588        11.0
# ESSEX                                              571        10.0
# BERGEN                                             466         8.0
# MIDDLESEX                                          463         8.0
# OCEAN                                              423         8.0
# PASSAIC                                            414         8.0
# UNION                                              375         7.0
# HUDSON                                             371         7.0
# CAMDEN                                             287         5.0
# MORRIS                                             219         4.0
# BURLINGTON                                         206         4.0
# MERCER                                             190         3.0
# SOMERSET                                           183         3.0
# ...

# %%
#create a bar chart

bar_chart = county_df_descending[['Total # of Cases by NJ County in June 2021']].plot(kind='bar', title ="Total # of Cases by NJ County in June 2021", figsize=(15, 10), legend=True, fontsize=12)

bar_chart

# %%
# total  data

# %%
# create t-test to see if correlation between June 2021 and total cumulative Covid cases by county

#Null hypothesis is the hypothesis that we are trying to disprove due to no statistical significance between the two variables.
#In short, you null hypothesis assumes that your results happened by chance.
#Alternative hypothesis (what researches what to prove) is the opposite of the null hypothesis, it assumes there is some factor influencing the results. The hypothesis assumes your results did not happen by chance.

#Research Question: Is there correlation between June 2021 num of cases and total cumulative cases by county
#Null : no correlation
#Alternative Hypothesis: very correlated (what we want to prove)

# %%
# 2019 population per NJ county; 2019 is the most recent data available
url_pop = "https://api.census.gov/data/2019/pep/charagegroups?get=NAME,POP&for=county:*&in=state:34&key=52e4b71218eb4d492e49c7dcde830174d23a8db9"


pop_response = requests.get(url_pop)
print(pop_response.url)
# Out:
# https://api.census.gov/data/2019/pep/charagegroups?get=NAME,POP&for=county:*&in=state:34&key=52e4b71218eb4d492e49c7dcde830174d23a8db9

# %%
pop_data = pop_response.json()
#print(json.dumps(pop_data, indent=4, sort_keys=True))
pop_df = pd.DataFrame(pop_data)
#pop_df

# %%
pop_df_simp = pd.DataFrame((pop_data), columns=("County","Population","State_Num","County_Num"))
pop_df_simp = pop_df_simp.drop(0).reset_index(drop=True)
pop_df_simp["County"] = pop_df_simp["County"].str.split(',',expand=True)
pop_df_simp["County"] = pop_df_simp["County"].str.split(' ',expand=True)
pop_df_simp["County_Num"] = pop_df_simp["State_Num"] + pop_df_simp["County_Num"]
pop_df_simp["Population"] = pop_df_simp["Population"].astype(float)
pop_df_simp['County'] = pop_df_simp['County'].str.upper()
pop_df_simp.set_index('County')
pop_df_simp.sort_values('Population',ascending=False)
# Out:
#         County  Population State_Num County_Num
# 13      BERGEN    932202.0        34      34003
# 20   MIDDLESEX    825062.0        34      34023
# 5        ESSEX    798975.0        34      34013
# 16      HUDSON    672391.0        34      34017
# 0     MONMOUTH    618795.0        34      34025
# 6        OCEAN    607186.0        34      34029
# 14       UNION    556341.0        34      34039
# 12      CAMDEN    506471.0        34      34007
# 10     PASSAIC    501826.0        34      34031
# 19      MORRIS    491845.0        34      34027
# 18  BURLINGTON    445349.0        34      34005
# 1       MERCER    367430.0        34      34021
# 4     SOMERSET    328934.0        34      34035
# 8   GLOUCESTER    291636.0        34      34015
# 7     ATLANTIC    263670.0        34      34001
# 3   CUMBERLAND    149527.0        34      34011
# 2       SUSSEX    140488.0        34      34037
# 17   HUNTERDON    124371.0        34      34019
# 15      WARREN    105267.0        34      34041
# ...

# %%
tot_pop = pop_df_simp["Population"].sum()
tot_pop
# Out:
# 8882190.0

# %%
#Research Question: Is there correlation between June 2021 num of cases and total population by county
#Null : no correlation
#Alternative Hypothesis: very correlated (what we want to prove)
