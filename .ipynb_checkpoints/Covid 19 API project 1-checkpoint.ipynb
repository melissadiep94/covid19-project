# %%
# Dependencies
import requests
import json
import pandas as pd
import numpy as np

# %%
from sodapy import Socrata
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-c650cb88f157> in <module>
# ----> 1 from sodapy import Socrata
#
# ModuleNotFoundError: No module named 'sodapy'

# %%
url = "https://data.cdc.gov/resource/n8mc-b4w4.json?res_state=NJ&case_month=2021-01&$limit=20000"

#how to filter for NJ first, date, and then 20000 cases?

# %%
response = requests.get(url)
print(response.url)
# Out:
# https://data.cdc.gov/resource/n8mc-b4w4.json?res_state=NJ&case_month=2021-01&$limit=20000

# %%
data = response.json()
# Use json.dumps to print the json
#print(json.dumps(data, indent=4, sort_keys=True))

#print data frame

df = pd.DataFrame(data)
df
# Out:
#       case_month res_state state_fips_code res_county county_fips_code  \
# 0        2021-01        NJ              34     MERCER            34021
# 1        2021-01        NJ              34     MERCER            34021
# 2        2021-01        NJ              34     MERCER            34021
# 3        2021-01        NJ              34     MERCER            34021
# 4        2021-01        NJ              34     MERCER            34021
# ...          ...       ...             ...        ...              ...
# 19995    2021-01        NJ              34      OCEAN            34029
# 19996    2021-01        NJ              34   CAPE MAY            34009
# 19997    2021-01        NJ              34     WARREN            34041
# 19998    2021-01        NJ              34      OCEAN            34029
# 19999    2021-01        NJ              34   CAPE MAY            34009
#
#             age_group     sex     race            ethnicity  \
# 0        0 - 17 years  Female  Unknown      Hispanic/Latino
# 1        0 - 17 years  Female  Unknown      Hispanic/Latino
# 2        0 - 17 years  Female  Unknown      Hispanic/Latino
# 3        0 - 17 years  Female  Unknown      Hispanic/Latino
# 4        0 - 17 years  Female  Unknown      Hispanic/Latino
# ...               ...     ...      ...                  ...
# 19995       65+ years  Female    White  Non-Hispanic/Latino
# 19996    0 - 17 years  Female    White  Non-Hispanic/Latino
# 19997  50 to 64 years    Male  Unknown              Missing
# 19998       65+ years  Female    White  Non-Hispanic/Latino
# 19999    0 - 17 years  Female    White  Non-Hispanic/Latino
#
#       case_onset_interval  process exposure_yn             current_status  \
# 0                     0.0  Missing     Missing  Laboratory-confirmed case
# 1                     0.0  Missing     Missing  Laboratory-confirmed case
# 2                     0.0  Missing     Missing  Laboratory-confirmed case
# 3                     0.0  Missing     Missing  Laboratory-confirmed case
# 4                     0.0  Missing     Missing              Probable Case
# ...                   ...      ...         ...                        ...
# 19995                 NaN  Missing     Missing  Laboratory-confirmed case
# 19996                 0.0  Missing     Missing              Probable Case
# 19997                 NaN  Missing     Missing              Probable Case
# 19998                 NaN  Missing     Missing  Laboratory-confirmed case
# 19999                 0.0  Missing     Missing              Probable Case
#
#       symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn  \
# 0        Symptomatic  Missing  Missing       No                      NaN
# 1        Symptomatic       No  Missing       No                      NaN
# 2        Symptomatic       No  Missing       No                      NaN
# 3        Symptomatic       No  Missing       No                      NaN
# 4        Symptomatic       No  Missing       No                      NaN
# ...              ...      ...      ...      ...                      ...
# 19995        Missing  Missing  Missing       No                      NaN
# 19996    Symptomatic       No  Missing       No                      NaN
# 19997        Missing  Missing  Missing       No                      NaN
# 19998        Missing       No  Missing       No                      NaN
# 19999    Symptomatic       No  Missing       No                      NaN
#
#       case_positive_specimen
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 19995                    NaN
# 19996                    NaN
# 19997                    NaN
# 19998                    NaN
# 19999                    NaN
#
# [20000 rows x 19 columns]

# %%
#Total # of cases

num_cases = df["res_state"].count()

df_cases = pd.DataFrame({"Total # of NJ cases in Sample":[num_cases]})
df_cases
# Out:
#    Total # of NJ cases in Sample
# 0                          20000

# %%
#Group by county
#county = df.groupby(['res_state','res_county']).count()

#county = df.groupby(['res_state','res_county']).size()

num_cases_county = df['res_county'].value_counts()

num_cases_county_percentage = (county/ 20000 ) * 100


county_df = pd.DataFrame({"Total # of Cases by County": num_cases_county, "Percentage": num_cases_county_percentage })
county_df.round()
# Out:
#             Total # of Cases by County  Percentage
# CAMDEN                            1435         7.0
# HUDSON                            1346         7.0
# OCEAN                             1176         6.0
# CUMBERLAND                        1159         6.0
# UNION                             1132         6.0
# SALEM                             1109         6.0
# MERCER                            1063         5.0
# BERGEN                            1025         5.0
# BURLINGTON                        1007         5.0
# MORRIS                            1003         5.0
# HUNTERDON                          946         5.0
# SUSSEX                             945         5.0
# GLOUCESTER                         926         5.0
# CAPE MAY                           904         5.0
# ATLANTIC                           897         4.0
# WARREN                             896         4.0
# PASSAIC                            890         4.0
# MIDDLESEX                          719         4.0
# MONMOUTH                           527         3.0
# SOMERSET                           515         3.0
# ESSEX                              380         2.0

# %%
#create a bar chart
