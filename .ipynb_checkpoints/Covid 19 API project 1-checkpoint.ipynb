# %%
# Dependencies
import requests
import json
import pandas as pd
import numpy as np

# %%
from sodapy import Socrata
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-c650cb88f157> in <module>
# ----> 1 from sodapy import Socrata
#
# ModuleNotFoundError: No module named 'sodapy'

# %%
url = "https://data.cdc.gov/resource/n8mc-b4w4.json?$limit=20000"

#how to filter for NJ first, date, and then 20000 cases?

# %%
response = requests.get(url)
print(response.url)
# Out:
# https://data.cdc.gov/resource/n8mc-b4w4.json?$limit=20000

# %%
data = response.json()
# Use json.dumps to print the json
#print(json.dumps(data, indent=4, sort_keys=True))

#print data frame

df = pd.DataFrame(data)
df
# Out:
#       case_month res_state state_fips_code res_county county_fips_code  \
# 0        2020-08        KY              21    GRAYSON            21085
# 1        2021-01        NC              37     MARTIN            37117
# 2        2021-03        VT              50   FRANKLIN            50011
# 3        2020-09        GA              13    CATOOSA            13047
# 4        2021-04        PA              42    CLINTON            42035
# ...          ...       ...             ...        ...              ...
# 19995    2020-05        MS              28    FORREST            28035
# 19996    2020-11        IN              18     GIBSON            18051
# 19997    2020-04        MS              28      HINDS            28049
# 19998    2020-12        MT              30       LAKE            30047
# 19999    2020-07        GA              13    LOWNDES            13185
#
#             age_group     sex     race ethnicity case_onset_interval  process  \
# ...

# %%
#Total # of cases

num_cases = df["res_state"].count()

df_cases = pd.DataFrame({"Total # of NJ cases in Sample":[num_cases]})
df_cases
# Out:
#    Total # of NJ cases in Sample
# 0                          20000

# %%
#Group by county
county = df.groupby(['res_county'])
county_unique = county.nunique()["county_fips_code"]

df_county = pd.DataFrame({"Total # of Cases by County": [county_unique]})
df_county
# Out:
#                           Total # of Cases by County
# 0  res_county
# ABBEVILLE      1
# ACCOMACK       1
# A...
