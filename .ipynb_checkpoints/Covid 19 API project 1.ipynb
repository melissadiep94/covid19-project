# %%
# Dependencies
import requests
import json
import pandas as pd

# %%
# The COVID-19 case surveillance database includes patient-level data reported by U.S. states and autonomous reporting entities, including New York City and the District of Columbia (D.C.), as well as U.S. territories and affiliates. 
url = "https://data.cdc.gov/resource/n8mc-b4w4.json"

# %%
response = requests.get(url)
print(response.url)
# Out:
# https://data.cdc.gov/resource/n8mc-b4w4.json

# %%
data = response.json()
# Use json.dumps to print the json
#print(json.dumps(data, indent=4, sort_keys=True))

#print data frame

df = pd.DataFrame(data)
df.head()
# Out:
#   case_month res_state state_fips_code res_county county_fips_code  \
# 0    2020-08        KY              21    GRAYSON            21085
# 1    2021-01        NC              37     MARTIN            37117
# 2    2021-03        VT              50   FRANKLIN            50011
# 3    2020-09        GA              13    CATOOSA            13047
# 4    2021-04        PA              42    CLINTON            42035
#
#         age_group     sex     race ethnicity case_onset_interval  process  \
# 0    0 - 17 years      NA       NA        NA                 0.0  Missing
# 1    0 - 17 years      NA       NA        NA                 NaN  Missing
# 2  18 to 49 years      NA       NA        NA                 0.0  Missing
# 3    0 - 17 years  Female  Unknown   Missing                 NaN  Missing
# 4    0 - 17 years  Female       NA        NA                 0.0  Missing
#
#   exposure_yn             current_status symptom_status  hosp_yn   icu_yn  \
# ...

# %%
# just NJ data frame

df_nj = df[df['res_state'] == "NJ"] 
df_nj
# Out:
#     case_month res_state state_fips_code  res_county county_fips_code  \
# 135    2021-01        NJ              34      MERCER            34021
# 146    2020-04        NJ              34       SALEM            34033
# 160    2021-04        NJ              34  GLOUCESTER            34015
# 349    2020-03        NJ              34      HUDSON            34017
# 355    2020-04        NJ              34   HUNTERDON            34019
# 419    2020-12        NJ              34      CAMDEN            34007
# 420    2020-04        NJ              34      MORRIS            34027
# 427    2021-04        NJ              34      BERGEN            34003
# 506    2021-04        NJ              34      WARREN            34041
# 595    2021-04        NJ              34    MONMOUTH            34025
# 865    2020-12        NJ              34  BURLINGTON            34005
# 939    2020-11        NJ              34   MIDDLESEX            34023
# ...

# %%
#Total # of cases

num_cases = df_nj["res_state"].count()

df_cases = pd.DataFrame({"Total # of NJ cases":[num_cases]})
df_cases
# Out:
#    Total # of NJ cases
# 0                   14

# %%
#Group by category, count of confirmed cases, underlying conditions (yes), hospitalized, icu, deaths
#1 Age Group
#2 race
#3 gender
