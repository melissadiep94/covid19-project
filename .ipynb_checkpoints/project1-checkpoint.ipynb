# %%
# Dependencies
import requests
import json
import pandas as pd

# %%
# URL for GET requests to retrieve data for Covid 19 cases from centre for diesase control and prevention
url = "https://data.cdc.gov/resource/n8mc-b4w4.json?res_state=NJ&$limit=20000"

# %%
# Print the response object to the console
response = requests.get(url)
print( response.url)
# Out:
# https://data.cdc.gov/resource/n8mc-b4w4.json?res_state=NJ

# %%
data = response.json()

data_df=pd.DataFrame(data)

data_df
# Out:
#     case_month res_state state_fips_code  res_county county_fips_code  \
# 0      2021-01        NJ              34      MERCER            34021
# 1      2020-04        NJ              34       SALEM            34033
# 2      2021-04        NJ              34  GLOUCESTER            34015
# 3      2020-03        NJ              34      HUDSON            34017
# 4      2020-04        NJ              34   HUNTERDON            34019
# ..         ...       ...             ...         ...              ...
# 995    2021-02        NJ              34       UNION            34039
# 996    2020-12        NJ              34    MONMOUTH            34025
# 997    2020-11        NJ              34      MERCER            34021
# 998    2021-03        NJ              34       OCEAN            34029
# 999    2021-04        NJ              34  BURLINGTON            34005
#
#           age_group     sex            race        ethnicity  \
# 0      0 - 17 years  Female         Unknown  Hispanic/Latino
# 1    18 to 49 years    Male         Unknown  Hispanic/Latino
# 2    18 to 49 years  Female  Multiple/Other  Hispanic/Latino
# 3    18 to 49 years  Female           Black  Hispanic/Latino
# 4    18 to 49 years  Female           White  Hispanic/Latino
# ..              ...     ...             ...              ...
# 995  18 to 49 years    Male           Black  Hispanic/Latino
# 996  18 to 49 years  Female         Unknown  Hispanic/Latino
# 997  18 to 49 years    Male         Unknown  Hispanic/Latino
# 998       65+ years  Female           White  Hispanic/Latino
# 999  18 to 49 years  Female  Multiple/Other  Hispanic/Latino
#
#     case_onset_interval  process exposure_yn             current_status  \
# 0                   0.0  Missing     Missing  Laboratory-confirmed case
# 1                   0.0  Missing     Missing  Laboratory-confirmed case
# 2                   0.0  Missing     Missing              Probable Case
# 3                   0.0  Missing     Missing  Laboratory-confirmed case
# 4                   0.0  Missing     Missing  Laboratory-confirmed case
# ..                  ...      ...         ...                        ...
# 995                 0.0  Missing     Missing              Probable Case
# 996                 0.0  Missing     Missing  Laboratory-confirmed case
# 997                 NaN  Missing     Missing  Laboratory-confirmed case
# 998                 NaN  Missing     Missing              Probable Case
# 999                 0.0  Missing     Missing              Probable Case
#
#     symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 0      Symptomatic  Missing  Missing       No                      NaN
# 1      Symptomatic       No  Unknown       No                      Yes
# 2      Symptomatic       No  Missing       No                      NaN
# 3      Symptomatic       No  Unknown       No                      NaN
# 4      Symptomatic       No  Unknown       No                      Yes
# ..             ...      ...      ...      ...                      ...
# 995    Symptomatic       No  Missing       No                      NaN
# 996    Symptomatic       No  Missing       No                      NaN
# 997        Missing  Missing  Missing       No                      NaN
# 998        Missing  Missing  Missing       No                      NaN
# 999    Symptomatic       No  Missing       No                      NaN
#
# [1000 rows x 18 columns]

# %%
# New Jersey Data for hospitalisation and number of cases

no_cases_NJ = data_df("res_state").count()
no_cases_NJ
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-f4a2177459ec> in <module>
#       1 # New Jersey Data for hospitalisation and number of cases
#       2
# ----> 3 no_cases_NJ = data_df("res_state").count()
#       4 no_cases_NJ
#
# TypeError: 'DataFrame' object is not callable
