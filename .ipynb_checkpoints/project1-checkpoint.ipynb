# %%
# Dependencies
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# URL for GET requests to retrieve data for Covid 19 cases from centre for diesase control and prevention
url = "https://data.cdc.gov/resource/n8mc-b4w4.json?res_state=NJ&case_month=2021-06&$limit=20000"

# %%
# Print the response object to the console
response = requests.get(url)
print( response.url)
# Out:
# https://data.cdc.gov/resource/n8mc-b4w4.json?res_state=NJ&case_month=2021-06&$limit=20000

# %%
# New Jersey Data 

data = response.json()

data_df = pd.DataFrame(data)

data_df
# Out:
#      case_month res_state state_fips_code  res_county county_fips_code  \
# 0       2021-06        NJ              34  CUMBERLAND            34011
# 1       2021-06        NJ              34  CUMBERLAND            34011
# 2       2021-06        NJ              34  CUMBERLAND            34011
# 3       2021-06        NJ              34  CUMBERLAND            34011
# 4       2021-06        NJ              34  CUMBERLAND            34011
# ...         ...       ...             ...         ...              ...
# 5499    2021-06        NJ              34          NA               NA
# 5500    2021-06        NJ              34          NA               NA
# 5501    2021-06        NJ              34          NA               NA
# 5502    2021-06        NJ              34          NA               NA
# 5503    2021-06        NJ              34          NA               NA
#
#            age_group     sex race ethnicity case_onset_interval  process  \
# 0     18 to 49 years  Female   NA        NA                 0.0  Missing
# 1     18 to 49 years  Female   NA        NA                 0.0  Missing
# 2     18 to 49 years  Female   NA        NA                 0.0  Missing
# 3     18 to 49 years  Female   NA        NA                 0.0  Missing
# 4     18 to 49 years  Female   NA        NA                 0.0  Missing
# ...              ...     ...  ...       ...                 ...      ...
# 5499  18 to 49 years      NA   NA        NA                 NaN  Missing
# 5500  18 to 49 years      NA   NA        NA                 NaN  Missing
# 5501  18 to 49 years      NA   NA        NA                 NaN  Missing
# 5502  18 to 49 years      NA   NA        NA                 NaN  Missing
# 5503  18 to 49 years      NA   NA        NA                 NaN  Missing
#
#      exposure_yn             current_status symptom_status  hosp_yn   icu_yn  \
# 0        Missing              Probable Case    Symptomatic       No  Missing
# 1        Missing  Laboratory-confirmed case    Symptomatic       No  Missing
# 2        Missing  Laboratory-confirmed case    Symptomatic       No  Missing
# 3        Missing  Laboratory-confirmed case    Symptomatic       No  Missing
# 4        Missing  Laboratory-confirmed case    Symptomatic      Yes  Missing
# ...          ...                        ...            ...      ...      ...
# 5499     Missing  Laboratory-confirmed case        Missing  Missing  Missing
# 5500     Missing              Probable Case        Missing  Missing  Missing
# 5501     Missing              Probable Case        Missing  Missing  Missing
# 5502     Missing  Laboratory-confirmed case        Missing  Missing  Missing
# 5503     Missing  Laboratory-confirmed case        Missing  Missing  Missing
#
#      death_yn underlying_conditions_yn
# 0          No                      NaN
# 1          No                      NaN
# 2          No                      NaN
# 3          No                      NaN
# 4          No                      NaN
# ...       ...                      ...
# 5499       No                      NaN
# 5500       No                      NaN
# 5501       No                      NaN
# 5502       No                      NaN
# 5503       No                      NaN
#
# [5504 rows x 18 columns]

# %%
# New Jersey data for hospitalisation 
df_hosp = data_df["hosp_yn"].value_counts()
df_hosp
# Out:
# No         2685
# Missing    2479
# Yes         340
# Name: hosp_yn, dtype: int64

# %%
# No of cases 
no_cases = data_df["res_state"].count()
df_cases = pd.DataFrame({"Total no. of cases in sample":[no_cases]})
df_cases
# Out:
#    Total no. of cases in sample
# 0                          5504

# %%
# Number of cases as per county by Groupby
cases_county = data_df["res_county"].value_counts()

cases_percentage = ( cases_county / 20000 ) * 100

county_df = pd.DataFrame({"Total Number of Cases per County": cases_county, "Percentage": cases_percentage })
                          
county_df_descending = county_df.sort_values('Total Number of Cases per County',ascending=False)
                          
county_df_descending.round()
# Out:
#             Total Number of Cases per County  Percentage
# MONMOUTH                                 588         3.0
# ESSEX                                    571         3.0
# BERGEN                                   466         2.0
# MIDDLESEX                                463         2.0
# OCEAN                                    423         2.0
# PASSAIC                                  414         2.0
# UNION                                    375         2.0
# HUDSON                                   371         2.0
# CAMDEN                                   287         1.0
# MORRIS                                   219         1.0
# BURLINGTON                               206         1.0
# MERCER                                   190         1.0
# SOMERSET                                 183         1.0
# GLOUCESTER                               127         1.0
# CUMBERLAND                               117         1.0
# NA                                       111         1.0
# SUSSEX                                    97         0.0
# ATLANTIC                                  88         0.0
# CAPE MAY                                  80         0.0
# HUNTERDON                                 65         0.0
# WARREN                                    51         0.0
# SALEM                                     12         0.0

# %%
# cleaning the data filterating values nah values out of data notna will return true and false value.
#notna will be false ,will clean the data.

data_df = data_df[data_df['case_onset_interval'].notna()]
data_df
# Out:
#      case_month res_state state_fips_code  res_county county_fips_code  \
# 0       2021-06        NJ              34  CUMBERLAND            34011
# 1       2021-06        NJ              34  CUMBERLAND            34011
# 2       2021-06        NJ              34  CUMBERLAND            34011
# 3       2021-06        NJ              34  CUMBERLAND            34011
# 4       2021-06        NJ              34  CUMBERLAND            34011
# ...         ...       ...             ...         ...              ...
# 5469    2021-06        NJ              34          NA               NA
# 5482    2021-06        NJ              34          NA               NA
# 5486    2021-06        NJ              34          NA               NA
# 5489    2021-06        NJ              34          NA               NA
# 5496    2021-06        NJ              34          NA               NA
#
#            age_group     sex race ethnicity case_onset_interval  process  \
# 0     18 to 49 years  Female   NA        NA                 0.0  Missing
# 1     18 to 49 years  Female   NA        NA                 0.0  Missing
# 2     18 to 49 years  Female   NA        NA                 0.0  Missing
# 3     18 to 49 years  Female   NA        NA                 0.0  Missing
# 4     18 to 49 years  Female   NA        NA                 0.0  Missing
# ...              ...     ...  ...       ...                 ...      ...
# 5469              NA      NA   NA        NA                 0.0  Missing
# 5482              NA      NA   NA        NA                 0.0  Missing
# 5486              NA      NA   NA        NA                 0.0  Missing
# 5489              NA      NA   NA        NA                 0.0  Missing
# 5496  18 to 49 years      NA   NA        NA                 0.0  Missing
#
#      exposure_yn             current_status symptom_status hosp_yn   icu_yn  \
# 0        Missing              Probable Case    Symptomatic      No  Missing
# 1        Missing  Laboratory-confirmed case    Symptomatic      No  Missing
# 2        Missing  Laboratory-confirmed case    Symptomatic      No  Missing
# 3        Missing  Laboratory-confirmed case    Symptomatic      No  Missing
# 4        Missing  Laboratory-confirmed case    Symptomatic     Yes  Missing
# ...          ...                        ...            ...     ...      ...
# 5469     Missing              Probable Case    Symptomatic      No  Missing
# 5482     Missing              Probable Case    Symptomatic      No  Missing
# 5486     Missing  Laboratory-confirmed case    Symptomatic      No  Missing
# 5489     Missing  Laboratory-confirmed case    Symptomatic     Yes  Missing
# 5496     Missing              Probable Case    Symptomatic      No  Missing
#
#      death_yn underlying_conditions_yn
# 0          No                      NaN
# 1          No                      NaN
# 2          No                      NaN
# 3          No                      NaN
# 4          No                      NaN
# ...       ...                      ...
# 5469       No                      NaN
# 5482       No                      NaN
# 5486       No                      NaN
# 5489       No                      NaN
# 5496       No                      NaN
#
# [2285 rows x 18 columns]

# %%
#coorelation between number of cases and hospitalisation

county = data_df["res_county"].unique()

cases = county_df["Total Number of Cases per County"]
x_axis = np.arange(len(cases))
plt.xticks(rotation='vertical')
plt.bar(county, cases, color='r', alpha=0.5, align="center")
# Out:
# <BarContainer object of 22 artists>
