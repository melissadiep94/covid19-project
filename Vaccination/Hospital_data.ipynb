# %%
import pandas as pd
import numpy as np
import requests
import time
from config import v_key

# %%
d_state_covid = pd.read_csv("Data/NJ state time series.csv" )
d_state_covid
# Out:
#              date country state           county   fips  lat  long  \
# 0      2020-01-22      US    NJ  Atlantic County  34001  NaN   NaN
# 1      2020-01-23      US    NJ  Atlantic County  34001  NaN   NaN
# 2      2020-01-24      US    NJ  Atlantic County  34001  NaN   NaN
# 3      2020-01-25      US    NJ  Atlantic County  34001  NaN   NaN
# 4      2020-01-26      US    NJ  Atlantic County  34001  NaN   NaN
# ...           ...     ...   ...              ...    ...  ...   ...
# 11314  2021-07-09      US    NJ    Warren County  34041  NaN   NaN
# 11315  2021-07-10      US    NJ    Warren County  34041  NaN   NaN
# 11316  2021-07-11      US    NJ    Warren County  34041  NaN   NaN
# 11317  2021-07-12      US    NJ    Warren County  34041  NaN   NaN
# 11318  2021-07-13      US    NJ    Warren County  34041  NaN   NaN
#
#                           locationId  actuals.cases  actuals.deaths  ...  \
# 0      iso1:us#iso2:us-nj#fips:34001            NaN             NaN  ...
# ...

# %%
#getting columns needed for hospital - beds 
d_state_covid_hospital_df=d_state_covid[['date','county','fips','actuals.hospitalBeds.capacity','actuals.hospitalBeds.currentUsageTotal',
                                   'actuals.icuBeds.capacity','actuals.icuBeds.currentUsageTotal','actuals.icuBeds.currentUsageCovid',
                                    'actuals.icuBeds.typicalUsageRate']]
d_state_covid_hospital_df
# Out:
#              date           county   fips  actuals.hospitalBeds.capacity  \
# 0      2020-01-22  Atlantic County  34001                            NaN
# 1      2020-01-23  Atlantic County  34001                            NaN
# 2      2020-01-24  Atlantic County  34001                            NaN
# 3      2020-01-25  Atlantic County  34001                            NaN
# 4      2020-01-26  Atlantic County  34001                            NaN
# ...           ...              ...    ...                            ...
# 11314  2021-07-09    Warren County  34041                            NaN
# 11315  2021-07-10    Warren County  34041                            NaN
# 11316  2021-07-11    Warren County  34041                            NaN
# 11317  2021-07-12    Warren County  34041                            NaN
# 11318  2021-07-13    Warren County  34041                            NaN
#
#        actuals.hospitalBeds.currentUsageTotal  actuals.icuBeds.capacity  \
# ...

# %%
d_state_covid_hospital_df.describe()
# Out:
#                fips  actuals.hospitalBeds.capacity  \
# count  11319.000000                            0.0
# mean   34021.000000                            NaN
# std       12.111136                            NaN
# min    34001.000000                            NaN
# 25%    34011.000000                            NaN
# 50%    34021.000000                            NaN
# 75%    34031.000000                            NaN
# max    34041.000000                            NaN
#
#        actuals.hospitalBeds.currentUsageTotal  actuals.icuBeds.capacity  \
# count                             1240.000000               1240.000000
# mean                               685.546774                123.804839
# std                                545.933948                114.340537
# min                                 39.000000                  7.000000
# 25%                                241.500000                 28.000000
# ...
